# %% [markdown]
# <a href="https://colab.research.google.com/github/champtanapat/COS3109/blob/main/Assignment_week_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ข้อ 1 Graph To Tree![1.png](data:image/png;base64,...)

# %% [markdown]
# ![assignment AI week 4_1 (1).png](data:image/png;base64,...)

# %% [markdown]
# # ข้อ 2 DFS, BSF, UCS![2.png](data:image/png;base64,...)

# %% [markdown]
# ![assignment AI week 4_1 (5).png](data:image/png;base64,...)![assignment AI week 4_1 (4).png](data:image/png;base64,...)![assignment AI week 4_1 (3).png](data:image/png;base64,...)

# %% [markdown]
# # ข้อ 3 ข้อดี Advantages ข้อเสีย Disadvantages![3.png](data:image/png;base64,...)

# %% [markdown]
# ![assignment AI week 4_1 (7).png](data:image/png;base64,...)![assignment AI week 4_1 (6).png](data:image/png;base64,...)
